# %%
# !rm youtube_clip.mp4

# %%
import yt_dlp

video_url = 'https://www.youtube.com/watch?v=m8Oyui5sGiI'
start_time = 51 * 60
end_time = 53 * 60
resolution = "480"
output_filename = "youtube_clip_50_52"

ydl_opts = {
    # Improved Format Selection:
    # This allows for more flexibility if a specific mp4 format is missing at 720p
    'format': f'bestvideo[height<={resolution}]+bestaudio/best[height<={resolution}]/best',
    'merge_output_format': 'mp4',
    'outtmpl': f'{output_filename}.%(ext)s',
    
    # Using firefox cookie for Auth
    'cookiesfrombrowser': ('firefox',),
    
    # Time Range Logic (The "Download Portion" part)
    'download_ranges': lambda info_dict, ydl: [{
        'start_time': start_time,
        'end_time': end_time,
    }],
    'force_keyframes_at_cuts': True,
    
    # FIX FOR "TLS Error / Code 187":
    # Using the 'ffmpeg' external downloader for the input stream specifically
    'external_downloader': {'default': 'ffmpeg'},
    'external_downloader_args': {
        'ffmpeg_i': [
            '-reconnect', '1', 
            '-reconnect_streamed', '1', 
            '-reconnect_delay_max', '5'
        ]
    },
    'quiet': False,
    'no_warnings': False,
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([video_url])
# Out:
# Extracting cookies from firefox
# Extracted 974 cookies from firefox
# [youtube] Extracting URL: https://www.youtube.com/watch?v=m8Oyui5sGiI
# [youtube] m8Oyui5sGiI: Downloading webpage
# [youtube] m8Oyui5sGiI: Downloading tv downgraded player API JSON
# [youtube] m8Oyui5sGiI: Downloading player 2d01abf7-main
# [youtube] [jsc:deno] Solving JS challenges using deno
# [youtube] m8Oyui5sGiI: Downloading m3u8 information
# [info] m8Oyui5sGiI: Downloading 1 format(s): 397+251
# [info] m8Oyui5sGiI: Downloading 1 time ranges: 3060.0-3180.0
# [download] Destination: youtube_clip_50_52.mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr2---sn-4g5ednks.googlevideo.com/videoplayback?expire=1778864365&ei=jfwGavbkGMuMv_IP88XhoQ8&ip=104.28.229.13&id=o-AJeGEidXsXhrFOaoqd4OnABN5XOVWX62OlKRCHpfqXgr&itag=397&aitags=133%2C134%2C135%2C136%2C160%2C242%2C243%2C244%2C247%2C278%2C298%2C299%2C302%2C303%2C308%2C315%2C394%2C395%2C396%2C397%2C398%2C399%2C400%2C401&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&cps=83&met=1778842765%2C&mh=T4&mm=31%2C26&mn=sn-4g5ednks%2Csn-oj1gi5-5b&ms=au%2Conr&mv=m&mvi=2&pl=24&rms=au%2Cau&initcwndbps=4752500&siu=1&bui=AbKmrwrVXoN_dsV30txQQvGBknA08LvYdGGruwqMcY7uTBXhcRmVYbAfReRwZF-9_9zqHIKxfA&vprv=1&svpuc=1&mime=video%2Fmp4&ns=ojwzvxrEfCseskOucYzH5XMV&rqh=1&gir=yes&clen=407454643&dur=4370.036&lmt=1771253114332795&mt=1778842179&fvip=4&keepalive=yes&lmw=1&fexp=51565115%2C51565681&c=TVHTML5&sefc=1&txp=3309224&n=o_K78mxz-wna8w&sparams=expire%2Cei%2Cip%2Cid%2Caitags%2Csource%2Crequiressl%2Cxpc%2Csiu%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2
native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5e88f5d9a040] using SAR=1/1
# [libx264 @ 0x5e88f5d9a040] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5e88f5d9a040] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5e88f5d9a040] 264 - core 165 - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'file:youtube_clip_50_52.mp4.part':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6av01mp41
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 854x480 [SAR 1:1 DAR 427:240], q=2-31, 29.97 fps, 11988 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       creation_time   : 2026-02-16T14:23:06.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       encoder         : Lavc62.11.100 aac
# frame= 3484 fps= 21 q=29.0 size=   36096KiB time=00:01:55.62 bitrate=2557.4kbits/s speed=0.709x elapsed=0:02:43.06
# [download] 100% of   35.83MiB in 00:02:47 at 218.82KiB/s
# [out#0/mp4 @ 0x5e88f5e40cc0] video:34684KiB audio:1876KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.354123%
# frame= 3597 fps= 22 q=-1.0 Lsize=   36690KiB time=00:01:59.98 bitrate=2505.0kbits/s speed=0.734x elapsed=0:02:43.57
# [libx264 @ 0x5e88f5d9a040] frame I:15    Avg QP:22.55  size: 87012
# [libx264 @ 0x5e88f5d9a040] frame P:1089  Avg QP:25.23  size: 21256
# [libx264 @ 0x5e88f5d9a040] frame B:2493  Avg QP:30.64  size:  4438
# [libx264 @ 0x5e88f5d9a040] consecutive B-frames:  3.2% 10.7%  7.6% 78.5%
# [libx264 @ 0x5e88f5d9a040] mb I  I16..4:  3.0% 55.1% 41.9%
# [libx264 @ 0x5e88f5d9a040] mb P  I16..4:  1.1%  7.0%  2.4%  P16..4: 30.9% 21.0% 14.0%  0.0%  0.0%    skip:23.7%
# [libx264 @ 0x5e88f5d9a040] mb B  I16..4:  0.1%  0.7%  0.3%  B16..8: 37.6%  6.8%  2.3%  direct: 2.0%  skip:50.2%  L0:29.6% L1:39.4% BI:31.0%
# [libx264 @ 0x5e88f5d9a040] 8x8 transform intra:64.6% inter:61.6%
# [libx264 @ 0x5e88f5d9a040] coded y,uvDC,uvAC intra: 80.0% 54.8% 15.8% inter: 20.3% 8.1% 0.6%
# [libx264 @ 0x5e88f5d9a040] i16 v,h,dc,p: 19% 43%  8% 30%
# [libx264 @ 0x5e88f5d9a040] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 24% 16%  5%  7%  6%  9%  6% 10%
# [libx264 @ 0x5e88f5d9a040] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 28% 12%  6%  7%  6%  8%  6%  8%
# [libx264 @ 0x5e88f5d9a040] i8c dc,h,v,p: 60% 22% 14%  5%
# [libx264 @ 0x5e88f5d9a040] Weighted P-Frames: Y:3.2% UV:1.0%
# [libx264 @ 0x5e88f5d9a040] ref P L0: 68.1% 20.7%  8.5%  2.6%  0.1%
# [libx264 @ 0x5e88f5d9a040] ref B L0: 95.1%  4.0%  0.9%
# [libx264 @ 0x5e88f5d9a040] ref B L1: 98.1%  1.9%
# [libx264 @ 0x5e88f5d9a040] kb/s:2367.33
# [aac @ 0x5e88f5d0c000] Qavg: 25850.225

# %%
from ultralytics import YOLO

# 1. Load your finetuned weights
model = YOLO('../models/best.pt')

# Export to TensorRT
# format='engine' creates the TensorRT file
# half=True uses FP16 precision (much faster on RTX 3050)
# device=0 ensures it uses your GPU for the conversion
model.export(
    format='onnx', 
    # device=0, 
    # half=True, 
    # imgsz=640, 
    # dynamic=False  # Set to True if you need variable input sizes
)
# Out:
# WARNING ⚠️ TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.4.48 🚀 Python-3.13.13 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3770MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.5 GFLOPs
#
# PyTorch: starting from '../models/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (19.4 MB)
#
# ONNX: starting export with onnx 1.21.0 opset 18...
# ONNX: slimming with onnxslim 0.1.93...
# ONNX: export success ✅ 1.0s, saved as '../models/best.onnx' (36.4 MB)
#
# TensorRT: starting export with TensorRT 10.16.1.11...
# [05/11/2026-19:21:23] [TRT] [W] WARNING The logger passed into createInferBuilder differs from one already registered for an existing builder, runtime, or refitter. So the current new logger is ignored, and TensorRT will use the existing one which is returned by nvinfer1::getLogger() instead.
# [05/11/2026-19:21:23] [TRT] [I] ----------------------------------------------------------------
# [05/11/2026-19:21:23] [TRT] [I] Input filename:   ../models/best.onnx
# [05/11/2026-19:21:23] [TRT] [I] ONNX IR version:  0.0.8
# [05/11/2026-19:21:23] [TRT] [I] Opset version:    18
# [05/11/2026-19:21:23] [TRT] [I] Producer name:    pytorch
# [05/11/2026-19:21:23] [TRT] [I] Producer version: 2.11.0
# [05/11/2026-19:21:23] [TRT] [I] Domain:
# [05/11/2026-19:21:23] [TRT] [I] Model version:    0
# [05/11/2026-19:21:23] [TRT] [I] Doc string:
# [05/11/2026-19:21:23] [TRT] [I] ----------------------------------------------------------------
# TensorRT: input "images" with shape(1, 3, 640, 640) DataType.FLOAT
# TensorRT: output "output0" with shape(1, 300, 6) DataType.FLOAT
# TensorRT: building FP32 engine as ../models/best.engine
# [05/11/2026-19:21:23] [TRT] [I] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [05/11/2026-19:21:55] [TRT] [I] Compiler backend is used during engine build.
# [05/11/2026-19:22:24] [TRT] [I] [GraphReduction] The approximate region cut reduction algorithm is called.
# [05/11/2026-19:22:24] [TRT] [I] Detected 1 inputs and 1 output network tensors.
# [05/11/2026-19:22:24] [TRT] [I] Total Host Persistent Memory: 619680 bytes
# [05/11/2026-19:22:24] [TRT] [I] Total Device Persistent Memory: 0 bytes
# [05/11/2026-19:22:24] [TRT] [I] Max Scratch Memory: 5529600 bytes
# [05/11/2026-19:22:24] [TRT] [I] [BlockAssignment] Started assigning block shifts. This will take 296 steps to complete.
# [05/11/2026-19:22:24] [TRT] [I] [BlockAssignment] Algorithm ShiftNTopDown took 19.1577ms to assign 13 blocks to 296 nodes requiring 37351424 bytes.
# [05/11/2026-19:22:24] [TRT] [I] Total Activation Memory: 37350400 bytes
# [05/11/2026-19:22:24] [TRT] [I] Total Weights Memory: 43468768 bytes
# [05/11/2026-19:22:24] [TRT] [I] Compiler backend is used during engine execution.
# [05/11/2026-19:22:24] [TRT] [I] Engine generation completed in 60.802 seconds.
# [05/11/2026-19:22:24] [TRT] [I] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 4 MiB, GPU 100 MiB
# TensorRT: export success ✅ 62.0s, saved as '../models/best.engine' (43.1 MB)
#
# Export complete (62.1s)
# Results saved to /home/ali/code/projects/adas_interface/models/best.engine
# Predict:         yolo predict task=detect model=../models/best.engine imgsz=640
# Validate:        yolo val task=detect model=../models/best.engine imgsz=640 data=model.yaml
# Visualize:       https://netron.app
# PosixPath('../models/best.engine')

# %%
# !./third_party/TensorRT-10.16/bin/trtexec \
    --onnx=models/best.onnx \
    --saveEngine=models/best_trt.engine \
    --fp16 \
    --device=0
